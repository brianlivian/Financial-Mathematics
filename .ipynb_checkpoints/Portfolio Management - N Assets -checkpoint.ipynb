# %% [markdown]
# # Mathematics of Finance
# # Project 2.1
# # Daniel Cohen, Brian Livian
# # 11/2/22

# %% [markdown]
# ## Formulas
# <font size="4"> $ [(uc^{-1}u^{T})^{2} \sigma_{0}^{2} - uc^{-1}u^{T}]\lambda_{2}^{2}
# + [uc^{-1}m^{T} + mc^{-1}u^{T} - 2m(uc^{-1}u^{T})\sigma_{0}^{2}]\lambda_{2}
# + (mc^{-1}u^{T})^{2}\sigma_{0}^{2} - mc^{-1}m^{T} = 0
# $ </font>
#
# <font size="8"> $ w = \frac{(m - \lambda_{2}u)c^{-1}}{2(m - \lambda_{2}u)c^{-1}u^{T}}$ </font>

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
stock1 = 'TSLA'
stock2 = 'AAPL'
stock3 = 'WMT'
data = yf.download(stock1 + ' ' + stock2 + ' ' + stock3,start="2021-01-01")
data = data['Adj Close']
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
dataPct = data.pct_change().dropna()

# %%
data.head()
# Out:
#                   AAPL        TSLA         WMT
# Date
# 2021-01-04  128.087082  243.256668  142.539383
# 2021-01-05  129.670715  245.036667  141.780640
# 2021-01-06  125.305794  251.993332  142.665863
# 2021-01-07  129.581635  272.013336  142.656128
# 2021-01-08  130.700089  293.339996  142.636688

# %%
dataPct.head()
# Out:
#                 AAPL      TSLA       WMT
# Date
# 2021-01-05  0.012364  0.007317 -0.005323
# 2021-01-06 -0.033662  0.028390  0.006244
# 2021-01-07  0.034123  0.079447 -0.000068
# 2021-01-08  0.008631  0.078403 -0.000136
# 2021-01-11 -0.023249 -0.078214  0.004501

# %%
plt.figure(figsize = (16,8), facecolor = 'white')
plt.subplot(2,1,1)
plt.plot(data, label = data.columns)
plt.title('Adj Close')
plt.legend()

plt.subplot(2,1,2)
plt.plot(dataPct, label = dataPct.columns)
plt.legend()
plt.title('Simple Returns')
plt.show()

# %%
dataPct.describe()
# Out:
#              AAPL        TSLA         WMT
# count  462.000000  462.000000  462.000000
# mean     0.000488    0.000477    0.000081
# std      0.018885    0.037671    0.013927
# min     -0.058680   -0.121841   -0.113758
# 25%     -0.010324   -0.021502   -0.006422
# 50%      0.000403    0.001637    0.000460
# 75%      0.012925    0.020459    0.008004
# max      0.075553    0.196412    0.051056

# %%
plt.figure(figsize = (16,8))
plt.subplot(1,2,1)
sns.heatmap(dataPct.cov(), annot = True, annot_kws={"fontsize":20})
plt.title('Covariance')
plt.subplot(1,2,2)
sns.heatmap(dataPct.corr(), annot = True, annot_kws={"fontsize":20})
plt.title('Corrleations')
plt.show()

# %% [markdown]
# ## Part 1

# %%
m = dataPct.mean().values
c = np.array(dataPct.cov())
u = np.ones(len(dataPct.columns))
wmin = np.dot(u,np.linalg.inv(c)) / np.dot(np.dot(u, np.linalg.inv(c)),np.transpose(u))
print('Weights: '+ str(data.columns.values) + str(wmin))
minMuv = np.dot(wmin, np.transpose(m))
print('Minimum Risk Portfolio Expectation = ' + str(minMuv))
minVarv = np.dot(np.dot(wmin, c), np.transpose(wmin))
print('Minimum Risk Portfolio Variance = ' + str(minVarv))
# Out:
# Weights: ['AAPL' 'TSLA' 'WMT'][ 0.30802858 -0.01420361  0.70617503]
# Minimum Risk Portfolio Expectation = 0.000200659192722916
# Minimum Risk Portfolio Variance = 0.00016061340165587315

# %% [markdown]
# ## Part 2: Increasing risk by 20%

# %%
# Increase risk by 20%
Var120P = (1.2 * np.sqrt(minVarv))**2

#Defining some values so calculation for quadratic is cleaner
m = dataPct.mean().values
c = np.array(dataPct.cov())
cinv = np.linalg.inv(c)
ucinv = np.dot(u, cinv)
mcinv = np.dot(m, cinv)

# Plugging in for formula given on top of notebook:
a = np.dot(ucinv, np.transpose(u))**2 * Var120P - np.dot(ucinv, np.transpose(u))
b = np.dot(ucinv, np.transpose(m)) + np.dot(mcinv, np.transpose(u)) - 2*np.dot(m,ucinv)*Var120P
c = np.dot(mcinv, np.transpose(u)) * Var120P - np.dot(mcinv, np.transpose(u))

# Define quadratic formula
def quadraticformula(a,b,c):
    return np.array([(-b + np.sqrt((b**2) - 4*a*c))/ (2*a), (-b - np.sqrt((b**2) - 4*a*c))/ (2*a)])

# Solve for lambda 2 using quadratic formula
lambda2 = quadraticformula(a,b,c)

# 1ambda1 irrelevant for this calculation
# lambda1 = (m - np.dot(lambda2,u))*np.dot(cinv, np.transpose(u))/2
# lambda1

# Solve for new weights (formula given on top of notebook)
# Note two sets of weights because quadratic formula (lambda2) gives two values. 
# Will pick the weights with higher expectation?
w = [(np.dot(m - lambda2[0] * u, cinv))/ np.dot(np.dot(m - lambda2[0]*u, cinv),np.transpose(u)),
     (np.dot(m - lambda2[1] * u, cinv))/ np.dot(np.dot(m - lambda2[1]*u, cinv),np.transpose(u))]
w = w[0] if np.dot(w,m)[0] > np.dot(w,m)[1] else w[1]
print('Weights: '+ str(data.columns.values) + str(w))
print('Expectation: ' + str(np.dot(w,m)))
# Out:
# Weights: ['AAPL' 'TSLA' 'WMT'][ 0.316323   -0.01479683  0.69847383]
# Expectation: 0.00020379737958095475
